# %% [markdown]
# <a href="https://colab.research.google.com/github/donlee4u/ML_Class/blob/main/Nonlinear_Regression_CVX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python
# # Reference : Lecture at Stanford University
# #             https://cs231n.github.io/python-numpy-tutorial/
#
# ## **Numpy**

# %%
import numpy as np

# %% [markdown]
# ### Numpy Array

# %%
A=np.array(4,)
print(A)

# %%
import numpy as np

a = np.arange(6).reshape(3, 2)
print(a)
matrix = np.matrix(a)
print(matrix)
asmatrix = np.asmatrix(a)
print(matrix)
a[1, 1] = 999
print(a)
print(matrix)
print(asmatrix)

# %%
import numpy as np
import cvxpy as cvx

# %%
f = np.array([[3], [3/2]])
print(f)
lb = np.array([[-1], [0]])
ub = np.array([[2], [3]])
x = cvx.Variable([2,1])
print(x)
obj = cvx.Minimize(-f.T@x)
constraints = [lb <= x, x <= ub]

prob = cvx.Problem(obj, constraints)
result = prob.solve()

print(x.value)
print(result)
# Out:
# [[3. ]
#  [1.5]]
# var73
# [[1.99999999]
#  [2.99999999]]
# -10.499999963109541

# %%
# y = theta0 + theta1*x + theta2*x^2 + noise
import numpy as np
import matplotlib.pyplot as plt
n = 100
x = -10 + 15*np.random.rand(n, 1)
noise = 10*np.random.randn(n, 1)

y = 10 + 2*x**2 + noise
#print(x)
plt.figure(figsize = (6, 5))
plt.title('True x and y', fontsize = 12)
plt.xlabel('X', fontsize = 12)
plt.ylabel('Y', fontsize = 12)
plt.plot(x, y, 'o', markersize = 4, label = 'actual data')
plt.xlim([np.min(x), np.max(x)])
plt.grid(alpha = 0.3)
plt.legend(fontsize = 12)
plt.show()

# %%
A = np.hstack([x**0, x, x**2])
A = np.asmatrix(A)

theta = (A.T*A).I*A.T*y
print('theta:\n', theta)
xp = np.linspace(np.min(x), np.max(x))
yp = theta[0,0] + theta[1,0]*xp + theta[2,0]*xp**2

plt.figure(figsize = (6, 5))
plt.plot(x, y, 'o', markersize = 4, label = 'actual data')
plt.plot(xp, yp, 'r', linewidth = 2, label = 'estimated')

plt.title('Nonlinear regression', fontsize = 12)
plt.xlabel('X', fontsize = 12)
plt.ylabel('Y', fontsize = 12)
plt.xlim([np.min(x), np.max(x)])
plt.grid(alpha = 0.3)
plt.legend(fontsize = 12)
plt.show()
# Out:
# theta:
#  [[8.05614832]
#  [0.26725988]
#  [2.07424597]]

# %%
# Overfitting

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# 10 data points
n = 10
x = np.linspace(-4.5, 4.5, 10).reshape(-1, 1)
y = np.array([0.9819, 0.7973, 1.9737, 0.1838, 1.3180, -0.8361, -0.6591, -2.4701, -2.8122, -6.2512]).reshape(-1, 1)

plt.figure(figsize = (6, 5))
plt.plot(x, y, 'o', label = 'Data')
plt.xlabel('X', fontsize = 12)
plt.ylabel('Y', fontsize = 12)
plt.grid(alpha = 0.3)
plt.axis('equal')
plt.show()

# %%
A = np.hstack([x**0, x])
A = np.asmatrix(A)

theta = (A.T*A).I*A.T*y
print(theta)
# Out:
# [[-0.7774    ]
#  [-0.71070424]]

# %%
# to plot
xp = np.arange(-4.5, 4.5, 0.01).reshape(-1, 1)
yp = theta[0,0] + theta[1,0]*xp

plt.figure(figsize = (6, 4))
plt.plot(x, y, 'o', label = 'Data')
plt.plot(xp[:,0], yp[:,0], linewidth = 2, label = 'Linear')
plt.title('Linear Regression', fontsize = 12)
plt.xlabel('X', fontsize = 12)
plt.ylabel('Y', fontsize = 12)
plt.legend(fontsize = 12)
plt.grid(alpha = 0.3)
plt.axis('equal')
plt.show()

# %%
A = np.hstack([x**0, x, x**2])
A = np.asmatrix(A)

theta = (A.T*A).I*A.T*y
print(theta)
# Out:
# [[ 0.33669062]
#  [-0.71070424]
#  [-0.13504129]]

# %%
# to plot
xp = np.arange(-4.5, 4.5, 0.01).reshape(-1, 1)
yp = theta[0,0] + theta[1,0]*xp + theta[2,0]*xp**2

plt.figure(figsize = (6, 4))
plt.plot(x, y, 'o', label = 'Data')
plt.plot(xp[:,0], yp[:,0], linewidth = 2, label = '2nd degree')
plt.title('Nonlinear Regression with Polynomial Functions', fontsize = 12)
plt.xlabel('X', fontsize = 12)
plt.ylabel('Y', fontsize = 12)
plt.legend(fontsize = 12)
plt.grid(alpha = 0.3)
plt.axis('equal')
plt.show()
